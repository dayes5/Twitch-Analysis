# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [  ] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# *Fill in your overview here*

# %% [markdown]
# # Names
#
# - Arushri Girish
# - Ronaldo Garcia-hernandez
# - Matthew Bernard
# - Daisy Ye
# - Jocelyn Quiroz

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# Is there a significant correlation between the percentage of followers gained and 1) new viewers and 2) watch time, before and during the pandemic?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# When the COVID-19 pandemic hit, many went into lockdown in an effort to limit the spread of the disease. When in-person social gatherings were limited, people instead looked to connect with others online “more than ever — for example social media engagement increased 61 percent during the first wave of the pandemic.” For many people in the midst of quarantine and lockdown, social media “has become a lifeline to the outside world” and an “important crutch for those looking for connection.” (Penn Medicine)
#
# The pandemic suddenly and drastically changed the way we interact with each other. People started to rely heavily on media technology more than ever to remain connected. This switch to online platforms as the primary source of staying in touch impacted the way we think of relationships. Our relationships to media figures likely became stronger with both real life relationships and parasocial relationships occurring over the screen and therefore parasocial relationships strongly resembling our personal relationships. (Psypost)
#
# The global pandemic during 2020 prompted a huge wave of people with other interests to take up live-streaming and/or watch streamers. The senior vice president of content at Twitch said “People are looking for a way to connect and when someone finds a community on Twitch, you become a regular viewer”(WSJ article).
#
#
# References (include links):
# - 1)https://www.psypost.org/2021/10/longitudinal-study-shows-how-parasocial-relationships-changed-over-time-during-the-covid-19-pandemic-61924
# - 2)https://www.wsj.com/articles/everyone-is-a-live-streamer-in-covid-19-era-11596965400
# - 3)https://www.pennmedicine.org/news/news-blog/2021/april/instagram-vs-reality-the-pandemics-impact-on-social-media-and-mental-health

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Yes, we hypothesize that there was an increase of parasocial relationships during covid, categorized by a strong positive correlation between the percentage of followers gained and the new viewers and watch time.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# *Fill in your dataset information here*
#
# (Copy this information for each dataset)
# - Dataset Name:
# - Link to the dataset:
# - Number of observations:
#
# 1-2 sentences describing each dataset.
#
# If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.

# %% [markdown]
# # Setup

# %%
# import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest
from statsmodels.stats.outliers_influence import variance_inflation_factor


# read the dataset from absolute path from local storage
january2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/january2019Data.csv')
february2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/february2019Data.csv')
march2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/march2019Data.csv')
april2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/april2019Data.csv')
may2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/may2019Data.csv')
june2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/june2019Data.csv')
july2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/july2019Data.csv')
august2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/august2019Data.csv')
september2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/september2019Data.csv')
october2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/october2019Data.csv')
november2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/november2019Data.csv')
december2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/december2019Data.csv')
january2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/january2020Data.csv')
february2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/february2020.csv')
march2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/march2020Data.csv')
april2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/april2020Data.csv')
may2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/may2020Data.csv')
june2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/june2020Data.csv')
july2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/july2020Data.csv')
august2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/august2020Data.csv')
september2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/september2020Data.csv')
october2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/october2020Data.csv')
november2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/november2020Data.csv')
december2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/december2020Data.csv')


# creating a list with the above datasets, to create a new dataframe
twitch2019And2020Data = [january2019Data, 
                         february2019Data, 
                         march2019Data, 
                         april2019Data, 
                         may2019Data, 
                         june2019Data, 
                         july2019Data,
                         august2019Data, 
                         september2019Data, 
                         october2019Data, 
                         november2019Data,
                         december2019Data,
                         january2020Data, 
                         february2020Data, 
                         march2020Data, 
                         april2020Data, 
                         may2020Data, 
                         june2020Data, 
                         july2020Data,
                         august2020Data, 
                         september2020Data, 
                         october2020Data, 
                         november2020Data, 
                         december2020Data]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
twitch2019And2020Data[0]
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0            1  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 1            2  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 2            3  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 3            4  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 4            5  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 5            6  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 6            7  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 7            8  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 8            9  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 9           10  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 10          11  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 11          12  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 12          13  https://static-cdn.jtvnw.net/jtv_user_pictures...
# ...

# %% [markdown]
# The data in the dataframes currently contains unnamed columns and columns which will not be used in the data analysis section. Therefore, we will be dropping the unnamed columns and the Partnered, Channel, Mature, Language, and Peek viewers columns for each dataframe.

# %%
# drop columns that are non numerical and not necessary for our project

for i in range(len(twitch2019And2020Data)):
    
    twitch2019And2020Data[i] = twitch2019And2020Data[i].loc[:, ~twitch2019And2020Data[i].columns.str.contains('^Unnamed')]
    twitch2019And2020Data[i] = twitch2019And2020Data[i].drop(columns=['Partnered', 'Channel', 'Mature', 'Language', 'Peak viewers', 'Average viewers'])

twitch2019And2020Data[0]
# Out:
#     Watch time  Stream time  Followers  Followers gained  Views gained
# 0   1172559300        10245    1895962            112041      25949896
# 1    645644160        13365   10859975            612304      13656428
# 2    520320210        14400    6054050            125422       7068511
# 3    446849160         9015   17458652            481553      14697668
# 4    424745010        18150    6356431            228864       5843345
# 5    375579150         4920    6039939             70166       9118167
# 6    304028670        13140    9985134            164852       9727291
# 7    276121665        16380   10039805             87664       4922657
# 8    263216295        10980    7016611            150643       5133021
# 9    261398550         6225     268191             56484       3829518
# 10   247515330         4995     540046             40653       5064801
# 11   244035255        14070    4639147            171236       4302751
# ...

# %% [markdown]
# The dataframes now only contain all the necessary columns needed for analysis. Still, the followers gained column does not represent standardize data since our data consists of huge streamers and smaller ones. Thus, we need to standardize the data by obtaining the percentage of followers gained for each streamer.

# %%
# Calculating the percent of followers gained and renaming the column
for i in range(len(twitch2019And2020Data)):
    twitch2019And2020Data[i]['Followers gained'] = twitch2019And2020Data[i]['Followers gained']/twitch2019And2020Data[i]['Followers']*100
    twitch2019And2020Data[i] = twitch2019And2020Data[i].rename(columns={"Followers gained": "Followers gained percent"})

twitch2019And2020Data[0]
# Out:
#     Watch time  Stream time  Followers  Followers gained percent  Views gained
# 0   1172559300        10245    1895962                  5.909454      25949896
# 1    645644160        13365   10859975                  5.638171      13656428
# 2    520320210        14400    6054050                  2.071704       7068511
# 3    446849160         9015   17458652                  2.758248      14697668
# 4    424745010        18150    6356431                  3.600511       5843345
# 5    375579150         4920    6039939                  1.161700       9118167
# 6    304028670        13140    9985134                  1.650974       9727291
# 7    276121665        16380   10039805                  0.873164       4922657
# 8    263216295        10980    7016611                  2.146948       5133021
# 9    261398550         6225     268191                 21.061109       3829518
# 10   247515330         4995     540046                  7.527692       5064801
# ...

# %% [markdown]
# Now that we have standardize the data, we are able to calculate the mean for each dataset.

# %%
# calculate mean of each dataset and input into new data frame
meanOfTwitchData= []
for i in range(len(twitch2019And2020Data)):
    meanOfTwitchData.append(twitch2019And2020Data[i].mean())      
meanOfTwitchData[0]
# Out:
# Watch time                  2.092014e+08
# Stream time                 1.436310e+04
# Followers                   3.253762e+06
# Followers gained percent    3.364383e+00
# Views gained                4.498842e+06
# dtype: float64

# %% [markdown]
# Since all of the dataframes in meanOfTwitchData have the same columns names and shape size, we are able to merge them into one dataframe.

# %%
meanOf2019Data = []
meanOf2020Data = []
for i in range(len(meanOfTwitchData)):
    if (i < 12):
        meanOf2019Data.append(meanOfTwitchData[i])
    else:
        meanOf2020Data.append(meanOfTwitchData[i])

# %%
df = pd.DataFrame(data=meanOfTwitchData) 
df2019 = pd.DataFrame(data=meanOf2019Data) 
df2020 = pd.DataFrame(data=meanOf2020Data)

# %%
df
# Out:
#      Watch time  Stream time   Followers  Followers gained percent  \
# 0   209201382.6      14363.1  3253762.00                  3.364383
# 1   221850504.9      14611.8  3190304.40                  3.840984
# 2   234208392.3      16997.4  2972227.60                  5.123747
# 3   200016601.2      13920.3  3094471.10                  3.173855
# 4   215793332.7      16003.2  3035476.70                  4.629738
# 5   221869355.7      14754.0  2953983.84                  2.615978
# 6   209149803.9      14958.9  2791761.06                  3.641863
# 7   256546738.2      12713.4  2624188.92                  4.285321
# 8   184612988.7      13045.5  2970375.98                  4.408761
# 9   209689442.7      14851.5  3337969.62                  2.227711
# 10  162797187.0      14646.6  2901734.78                  2.003992
# 11  148392190.5      13292.7  2866367.58                  1.982186
# 12  191787729.9      13939.5  3025844.46                  2.842344
# ...

# %% [markdown]
# Our data is now clean and ready to use for analysis. We removed the columns that contained streamer usernames for ethical purposes. We also removed any variables that were not necessary for our data, which include the columns, 'Partnered’, 'Channel', 'Mature', 'Language', 'Average viewers', and 'Peak Viewers'. The first four columns listed do not provide us with information relating to the formation or absence of parasocial relationships, rather it describes the type of content a streamer is making. The ‘Peak Viewers’ column is unnecessary because we are looking at new relationships that are formed; looking at the ‘Views Gained’ and ‘Followers Gained’ will describe new activity from the users.
# In order to standardize the data, we converted both the followers and views gained into a percentage to keep the data consistent for both smaller and larger streamers. Taking each of our clean monthly datasets, we found the mean of each column and combined them into a new dataset, consisting of 24 months, including the time before and during the pandemic.

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# First, we run pairplot to see if there us any indication of a crrelation between each column in the given dataset.

# %%
sns.pairplot(data=df)

# %% [markdown]
# Based on the pairplot finding, there is no immediate correlation that we can identify from the pairplot. However, that does not neccessarily mean that there are no correlations within the data. Further analysis on the data would have to be done to idenitfy correlations within specific categories.

# %%
df['Watch time'].plot(kind='bar')
plt.title('Watch Time over the Months')
plt.ylabel('Watch Time')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# The barplot describing the watch time over the two years shows a large spike at month 15.
# Months 0-11 are the consecutive months of 2019. Months 12-23 are the consecutive months of 2020.
# Month 15 would be April 2020. This is around the time that most countries have a presence of Covid
# and are in some form of lockdown. During this time, based on our barplot we can say that twitch users
# were increasingly watching streams. After month 15, we still see a general increase in the watch time.

# %%
df['Stream time'].plot(kind='bar')
plt.title('Stream Time over the Months')
plt.ylabel('Stream Time')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# This barplot shows the stream time from 2019-2020, with hours streamed shown on the y-axis.
# Overall, there is a slight decrease in stream time as time goes on. Months 2 and 4 have the highest hours
# of stream time, and months 6, 7, 18 and 19 have a notably lower number of hours streamed.

# %%
df['Followers gained percent'].plot(kind='bar')
plt.title('Percent of Followers Gained over the Months')
plt.ylabel('Percent of Followers Gained')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# This barplot depicts the percentage of followers gained on Twitch each month.
# Months 9-11, at the end of 2019, have the lowest percent of followers gained.
# Noticeably, month 15 ( April 2020), when lockdown is implemented for many countries, sees
# a large increase in followers gained–at double the average percentages of the other months.
# On average, months 15-23, which match the time of lockdown for many countries, see a larger
# increase in percent of followers gained, than the months preceding them.

# %%
df['Views gained'].plot(kind='bar')
plt.title('Percent of Followers Gained over the Months')
plt.ylabel('Percent of Followers Gained')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# This barplot shows the number of views gained, in millions, per month over the course of two years.
# From months 1-9, the number of views gained is fairly stable, at around 5-6 million.
# There is a dip in the number of views towards the end of 2019 and into 2020 (months 10-12).
# While month 13 and 14 match the trend of months 1-9, month 15 again sees a spike in Twitch activity,
# going over 9 million views gained. Afterwards, the average number of views gained is also higher than before
# month 15.

# %%
df['Views gained'].plot(kind='bar')
plt.title('Views Gained over the Months')
plt.ylabel('Views Gained')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# This barplot shows the number of views gained, in millions, per month over the course of two years.
# From months 1-9, the number of views gained is fairly stable, at around 5-6 million.
# There is a dip in the number of views towards the end of 2019 and into 2020 (months 10-12).
# While month 13 and 14 match the trend of months 1-9, month 15 again sees a spike in Twitch activity,
# going over 9 million views gained. Afterwards, the average number of views gained is also higher than before
# month 15.

# %%
sns.lmplot(x="Views gained", y="Followers gained percent", data=df2019, aspect=2)
plt.title('Views Gained vs. Followers gained percent 2019')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %% [markdown]
# <!-- This graph suggests there is not a strong correlation between views gained and stream time.
# This is mainly due to the large number of outliers present with no real pattern.
# For example, a couple outliers suggest a strong positive correlation like the stream times
# around 15200 while others suggest a negative correlation such as those right under 15000. -->
#
# Update

# %%
sns.lmplot(y="Followers gained percent", x="Views gained", data=df2020, aspect=2)
plt.title('Views Gained vs. Followers gained percent 2020')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %%
sns.lmplot(y="Followers gained percent", x="Watch time", data=df2019, aspect=2)
plt.title('Percentage of Followers Gained vs. Watch Time 2019')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %% [markdown]
# <!-- This graph also shows that there is not a very strong correlation between stream time and percentage
# of followers gained due to the large number of outliers. Despite the fact that there are a couple
# outliers suggesting a very strong positive correlation, it can be seen that there are many data
# points below the linear regression line that suggest that longer stream times do not necessarily
# imply more followers gained. -->
#
# Update

# %%
sns.lmplot(y="Followers gained percent", x="Watch time", data=df2020, aspect=2)
plt.title('Percentage of Followers Gained vs. Watch Time 2020')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %%
sns.lmplot(y="Followers gained percent", x="Stream time", data=df2019, aspect=2)
plt.title('Followers gained percent vs. Stream Time 2019')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %% [markdown]
# <!-- The graph below shows the correlation between watch time and followers gained.
# We observe a strong positive correlation. This means that with an increasing watch time over the two years,
# the followers a streamer gained also increased. -->
#
# Update

# %%
sns.lmplot(y="Followers gained percent", x="Stream time", data=df2020, aspect=2)
plt.title('Followers gained percent vs. Stream Time 2020')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %%
sns.heatmap(df2019.loc[:, ['Stream time', 'Watch time', 'Followers gained percent', 'Views gained']].corr(), annot=True, vmin=-1, vmax=1)
plt.title('Heatmap of All Variables Considered 2019')
# Out:
# Text(0.5, 1.0, 'Heatmap of All Variables Considered 2019')

# %% [markdown]
# <!-- After creating lmplots, we decided to create a Heatmap comparing all five variables to understand the correlation
# between each. Similar to what we noticed in our lmplots, Watch time shows a strong positive correlation with
# the percent of Followers gained, Average Viewers and Views Gained. This means that there is an increase in the
# number of new interactions by twitch users with top streamers over the course of the two years (2019 and 2020).
# Stream time shows weak correlations with the other variables, meaning that the hours streamed by top streamers
# over the two years had no correlation with the user interactions. -->
#
# Update
# Talk about Watch time vs Stream time

# %%
sns.heatmap(df2020.loc[:, ['Stream time', 'Watch time', 'Followers gained percent', 'Views gained']].corr(), annot=True, vmin=-1, vmax=1)
plt.title('Heatmap of All Variables Considered 2020')
# Out:
# Text(0.5, 1.0, 'Heatmap of All Variables Considered 2020')

# %%
sns.heatmap(df.loc[:, ['Stream time', 'Watch time', 'Followers gained percent', 'Views gained']].corr(), annot=True, vmin=-1, vmax=1)
plt.title('Heatmap of All Variables Considered')
# Out:
# Text(0.5, 1.0, 'Heatmap of All Variables Considered')

# %%
def find_outliers(column):
    col_mean = df[column].mean()
    col_sd = np.std(df[column])
    outliers = []

    for item in df[column]:
        if item > (col_mean + (col_sd * 2)):
            outliers.append(item)
        elif item < (col_mean - (col_sd * 2)):
            outliers.append(item)

    return outliers

Watchtime_outliers = find_outliers('Watch time')

Streamtime_outliers = find_outliers('Stream time')

Followers_outliers = find_outliers('Followers')

Followers_gained_percent_outliers = find_outliers('Followers gained percent')

Views_gained_outliers = find_outliers('Views gained')
print(Watchtime_outliers, Streamtime_outliers, Followers_outliers, Followers_gained_percent_outliers, Views_gained_outliers)
# Out:
# [413025024.0] [16997.4, 11999.1] [] [10.370438465102357, 7.836725776270088] [3117544.18, 8965265.0]

# %% [markdown]
# * Discuss the outliners and why we can't remove them

# %%
df2 = df2019[['Views gained', 'Followers gained percent']]
df2.columns = ['Views_gained', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Views_gained ~ Followers_gained_percent', df2) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Views_gained   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.561
# Method:                 Least Squares   F-statistic:                     15.07
# Date:                Fri, 11 Mar 2022   Prob (F-statistic):            0.00305
# Time:                        22:18:47   Log-Likelihood:                -174.50
# No. Observations:                  12   AIC:                             353.0
# Df Residuals:                      10   BIC:                             354.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 2.988e+06   5.56e+05      5.374      0.000    1.75e+06    4.23e+06
# ...

# %%
df3 = df2020[['Views gained', 'Followers gained percent']]
df3.columns = ['Views_gained', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Views_gained ~ Followers_gained_percent', df3) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Views_gained   R-squared:                       0.462
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                     8.573
# Date:                Fri, 11 Mar 2022   Prob (F-statistic):             0.0151
# Time:                        22:18:49   Log-Likelihood:                -180.66
# No. Observations:                  12   AIC:                             365.3
# Df Residuals:                      10   BIC:                             366.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 4.843e+06   6.35e+05      7.630      0.000    3.43e+06    6.26e+06
# ...

# %%
df4 = df2019[['Watch time', 'Followers gained percent']]
df4.columns = ['Watch_time', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Watch_time ~ Followers_gained_percent', df4) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Watch_time   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.332
# Method:                 Least Squares   F-statistic:                     6.470
# Date:                Fri, 11 Mar 2022   Prob (F-statistic):             0.0292
# Time:                        22:18:53   Log-Likelihood:                -219.97
# No. Observations:                  12   AIC:                             443.9
# Df Residuals:                      10   BIC:                             444.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 1.463e+08   2.46e+07      5.951      0.000    9.15e+07    2.01e+08
# ...

# %%
df5 = df2020[['Watch time', 'Followers gained percent']]
df5.columns = ['Watch_time', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Followers_gained_percent ~ Watch_time', df5) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Followers_gained_percent   R-squared:                       0.638
# Model:                                  OLS   Adj. R-squared:                  0.602
# Method:                       Least Squares   F-statistic:                     17.65
# Date:                      Fri, 11 Mar 2022   Prob (F-statistic):            0.00183
# Time:                              22:18:58   Log-Likelihood:                -20.091
# No. Observations:                        12   AIC:                             44.18
# Df Residuals:                            10   BIC:                             45.15
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.1599      1.912     -1.653      0.129      -7.420       1.100
# ...

# %%
df6 = df[['Watch time', 'Followers gained percent']]
df6.columns = ['Watch_time', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Watch_time ~ Followers_gained_percent', df6) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Watch_time   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     35.25
# Date:                Fri, 11 Mar 2022   Prob (F-statistic):           5.64e-06
# Time:                        22:18:56   Log-Likelihood:                -451.95
# No. Observations:                  24   AIC:                             907.9
# Df Residuals:                      22   BIC:                             910.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 1.366e+08   1.93e+07      7.090      0.000    9.67e+07    1.77e+08
# ...

# %%
df7 = df[['Views gained', 'Followers gained percent']]
df7.columns = ['Views_gained', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Views_gained ~ Followers_gained_percent', df7) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Views_gained   R-squared:                       0.531
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     24.92
# Date:                Fri, 11 Mar 2022   Prob (F-statistic):           5.37e-05
# Time:                        22:19:03   Log-Likelihood:                -361.46
# No. Observations:                  24   AIC:                             726.9
# Df Residuals:                      22   BIC:                             729.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 3.767e+06   4.44e+05      8.483      0.000    2.85e+06    4.69e+06
# ...

# %%
df8 = df[['Followers gained percent', 'Views gained', 'Stream time']]
df8.columns = ['Followers_gained_percent', 'Views_gained', 'Stream_time']
(outcome, predictors) = patsy.dmatrices('Followers_gained_percent ~ Views_gained + Stream_time', df8) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Followers_gained_percent   R-squared:                       0.534
# Model:                                  OLS   Adj. R-squared:                  0.489
# Method:                       Least Squares   F-statistic:                     12.01
# Date:                      Fri, 11 Mar 2022   Prob (F-statistic):           0.000333
# Time:                              22:23:08   Log-Likelihood:                -38.908
# No. Observations:                        24   AIC:                             83.82
# Df Residuals:                            21   BIC:                             87.35
# Df Model:                                 2
# Covariance Type:                  nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
df8 = df[['Followers gained percent', 'Watch time', 'Stream time']]
df8.columns = ['Followers_gained_percent', 'Watch_time', 'Stream_time']
(outcome, predictors) = patsy.dmatrices('Followers_gained_percent ~ Watch_time + Stream_time', df8) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Followers_gained_percent   R-squared:                       0.629
# Model:                                  OLS   Adj. R-squared:                  0.593
# Method:                       Least Squares   F-statistic:                     17.77
# Date:                      Fri, 11 Mar 2022   Prob (F-statistic):           3.04e-05
# Time:                              22:23:59   Log-Likelihood:                -36.174
# No. Observations:                        24   AIC:                             78.35
# Df Residuals:                            21   BIC:                             81.88
# Df Model:                                 2
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Is our data ethically sourced?
# All of our data is from SullyGnome.com, a website that is open to public and academic use. Because of this, there are not many privacy or ethical concerns about using this data.
# We also followed the website’s Terms and Conditions, in that we give credit to the site here, did not take large amounts of data from the site, and did not use any form of automated scraping on the site.
#
# Is our data respectful of Twitch users’ privacy?
# We decided to focus our analysis on the numerical means of stream time, watch time, average viewers, and followers gained per month for the top streamers of Twitch. Because we are using the means of stream time and viewers for every month, and have removed streamers’ usernames and languages from our data, there should be no personally identifiable data on the streamers. Our data also does not include any personal information on their viewers, but simply the sum and mean of time watched and followers gained. Since the data includes no personally identifiable information about the viewers, our data collection and analysis method should eliminate privacy concerns regarding Twitch users–for both streamers and viewers.
#
# Is our data unbiased?
# Because SullyGnome.com collects this data through the Twitch API, the data cannot be influenced by human bias. The data is numerical by nature, and there is thus no possibility of human influence or experimenter bias.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# *Fill in your discussion information here*

# %% [markdown]
# # Team Contributions

# %% [markdown]
# *Specify who in your group worked on which parts of the project.*
