# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [X] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# An increase in social media usage has been observed during the lockdowns of covid. Social Media is well-known to correlate with parasocial relationships, in which a media user engages in a one-sided relationship with a media persona. Our group wanted to understand if there was an increase in such parasocial relationships due to covid. We specifically analyzed twitch data from the years 2019 and 2020, looking at how the watch time and views gained, correlated with the number of followers gained by a streamer. Our results showed an increase in correlation between followers gained and watch time during covid, but a decrease in correlation between followers gained and views gained.

# %% [markdown]
# # Names
#
# - Arushri Girish
# - Ronaldo Garcia-Hernandez
# - Matthew Bernard
# - Daisy Ye
# - Jocelyn Quiroz

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# Is there an increase in parasocial relationships on twitch, marked by a significant correlation between the followers gained and 1) new viewers and 2) watch time, during the pandemic(2020) ?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# The pandemic suddenly and drastically changed the way we interact with each other. People started to rely heavily on media technology more than ever to remain connected. This switch to online platforms as the primary source of staying in touch impacted the way we think of relationships. Considering how media technology became the main source of communication with loved ones during the pandemic, our relationships with media figures may come to mimic the way we process our relationships with real-life friends and family, with both occurring over screens. Furthermore, “the data suggest that the more time we spend communicating with our real-life friends via screens, the stronger we begin to perceive our parasocial relationships with media figures" (Psypost).
#
# Our heavy reliance on screen communication, as well as parasocial relationships’ strong resemblance of our personal relationships, have potentially blurred cognitive distinctions between loved ones in real life and media figures during the pandemic.
#
# In particular, the global pandemic during 2020 prompted a huge wave of people with other interests to take up live-streaming and/or watch streamers. The senior vice president of content at Twitch said “People are looking for a way to connect and when someone finds a community on Twitch, you become a regular viewer”(WSJ article). This leads us to believe that there is an increase in parasocial relationships between viewers and streamers on Twitch during COVID (a time of high reliance on screen communication). In our project we considered the commitment and start of a parasocial, one sided, relationship as a “follow”. When twitch users follow a streamer, they are creating a stronger commitment.
#
#
#
# References (include links):
# - 1)https://www.psypost.org/2021/10/longitudinal-study-shows-how-parasocial-relationships-changed-over-time-during-the-covid-19-pandemic-61924
# - 2)https://www.pennmedicine.org/news/news-blog/2021/april/instagram-vs-reality-the-pandemics-impact-on-social-media-and-mental-health

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Yes, we hypothesize that there was an increase of parasocial relationships during covid, categorized by a strong positive correlation between the percentage of followers gained and the new viewers and watch time.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# 2019 Datasets: <br>
# https://sullygnome.com/channels/2019january/watched <br>
# https://sullygnome.com/channels/2019february/watched <br>
# https://sullygnome.com/channels/2019march/watched <br>
# https://sullygnome.com/channels/2019april/watched <br>
# https://sullygnome.com/channels/2019may/watched<br>
# https://sullygnome.com/channels/2019june/watched<br>
# https://sullygnome.com/channels/2019july/watched<br>
# https://sullygnome.com/channels/2019august/watched<br>
# https://sullygnome.com/channels/2019september/watched<br>
# https://sullygnome.com/channels/2019october/watched<br>
# https://sullygnome.com/channels/2019november/watched<br>
# https://sullygnome.com/channels/2019december/watched<br>
#
# Each of the 12 datasets, one for each month in 2019, contain data of the 50 most watched streamers including their watch time, stream time, views gained, followers gained, and followers.
#
#
# 2020 Datasets:<br>
# https://sullygnome.com/channels/2020january/watched<br>
# https://sullygnome.com/channels/2020february/watched<br>
# https://sullygnome.com/channels/2020march/watched<br>
# https://sullygnome.com/channels/2020april/watched<br>
# https://sullygnome.com/channels/2020may/watched<br>
# https://sullygnome.com/channels/2020june/watched<br>
# https://sullygnome.com/channels/2020july/watched<br>
# https://sullygnome.com/channels/2020august/watched<br>
# https://sullygnome.com/channels/2020september/watched<br>
# https://sullygnome.com/channels/2020october/watched<br>
# https://sullygnome.com/channels/2020november/watched<br>
# https://sullygnome.com/channels/2020december/watched<br>
#
#
# Each of the 12 datasets, one for each month in 2020, contain data of the 50 most watched streamers including their watch time, stream time, views gained, followers gained, and followers.
#
#
# We will create three total datasets. One dataset will include an overall time frame of both years. This will include 24 rows, and will take the means of each column in the monthly data set. We will also create a separate dataset for 2019 only and 2020 only, again using the original 24 datasets. Our individual 2019 and 2020 datasets will each contain twelve rows.

# %% [markdown]
# # Setup

# %%
# import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest
from statsmodels.stats.outliers_influence import variance_inflation_factor


# read the dataset from absolute path from local storage
january2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/january2019Data.csv')
february2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/february2019Data.csv')
march2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/march2019Data.csv')
april2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/april2019Data.csv')
may2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/may2019Data.csv')
june2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/june2019Data.csv')
july2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/july2019Data.csv')
august2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/august2019Data.csv')
september2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/september2019Data.csv')
october2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/october2019Data.csv')
november2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/november2019Data.csv')
december2019Data = pd.read_csv('/Users/ronaldog/Documents/twitch2019/december2019Data.csv')
january2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/january2020Data.csv')
february2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/february2020.csv')
march2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/march2020Data.csv')
april2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/april2020Data.csv')
may2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/may2020Data.csv')
june2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/june2020Data.csv')
july2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/july2020Data.csv')
august2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/august2020Data.csv')
september2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/september2020Data.csv')
october2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/october2020Data.csv')
november2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/november2020Data.csv')
december2020Data = pd.read_csv('/Users/ronaldog/Documents/twitch2020/december2020Data.csv')


# creating a list with the above datasets, to create a new dataframe
twitch2019And2020Data = [january2019Data, 
                         february2019Data, 
                         march2019Data, 
                         april2019Data, 
                         may2019Data, 
                         june2019Data, 
                         july2019Data,
                         august2019Data, 
                         september2019Data, 
                         october2019Data, 
                         november2019Data,
                         december2019Data,
                         january2020Data, 
                         february2020Data, 
                         march2020Data, 
                         april2020Data, 
                         may2020Data, 
                         june2020Data, 
                         july2020Data,
                         august2020Data, 
                         september2020Data, 
                         october2020Data, 
                         november2020Data, 
                         december2020Data]

# %% [markdown]
# # Data Cleaning

# %%
twitch2019And2020Data[0]
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0            1  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 1            2  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 2            3  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 3            4  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 4            5  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 5            6  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 6            7  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 7            8  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 8            9  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 9           10  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 10          11  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 11          12  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 12          13  https://static-cdn.jtvnw.net/jtv_user_pictures...
# ...

# %% [markdown]
# The data in the dataframes currently contains unnamed columns and columns which will not be used in the data analysis section. Therefore, we will be dropping the unnamed columns and the Partnered, Channel, Mature, Language, and Peek viewers columns for each dataframe.

# %%
# drop columns that are non numerical and not necessary for our project

for i in range(len(twitch2019And2020Data)):
    
    twitch2019And2020Data[i] = twitch2019And2020Data[i].loc[:, ~twitch2019And2020Data[i].columns.str.contains('^Unnamed')]
    twitch2019And2020Data[i] = twitch2019And2020Data[i].drop(columns=['Partnered', 'Channel', 'Mature', 'Language', 'Peak viewers', 'Average viewers'])

twitch2019And2020Data[0]
# Out:
#     Watch time  Stream time  Followers  Followers gained  Views gained
# 0   1172559300        10245    1895962            112041      25949896
# 1    645644160        13365   10859975            612304      13656428
# 2    520320210        14400    6054050            125422       7068511
# 3    446849160         9015   17458652            481553      14697668
# 4    424745010        18150    6356431            228864       5843345
# 5    375579150         4920    6039939             70166       9118167
# 6    304028670        13140    9985134            164852       9727291
# 7    276121665        16380   10039805             87664       4922657
# 8    263216295        10980    7016611            150643       5133021
# 9    261398550         6225     268191             56484       3829518
# 10   247515330         4995     540046             40653       5064801
# 11   244035255        14070    4639147            171236       4302751
# ...

# %% [markdown]
# The dataframes now only contain all the necessary columns needed for analysis. Still, the followers gained column does not represent standardize data since our data consists of huge streamers and smaller ones. Thus, we need to standardize the data by obtaining the percentage of followers gained for each streamer.

# %%
# Calculating the percent of followers gained and renaming the column
for i in range(len(twitch2019And2020Data)):
    twitch2019And2020Data[i]['Followers gained'] = twitch2019And2020Data[i]['Followers gained']/twitch2019And2020Data[i]['Followers']*100
    twitch2019And2020Data[i] = twitch2019And2020Data[i].rename(columns={"Followers gained": "Followers gained percent"})

twitch2019And2020Data[0]
# Out:
#     Watch time  Stream time  Followers  Followers gained percent  Views gained
# 0   1172559300        10245    1895962                  5.909454      25949896
# 1    645644160        13365   10859975                  5.638171      13656428
# 2    520320210        14400    6054050                  2.071704       7068511
# 3    446849160         9015   17458652                  2.758248      14697668
# 4    424745010        18150    6356431                  3.600511       5843345
# 5    375579150         4920    6039939                  1.161700       9118167
# 6    304028670        13140    9985134                  1.650974       9727291
# 7    276121665        16380   10039805                  0.873164       4922657
# 8    263216295        10980    7016611                  2.146948       5133021
# 9    261398550         6225     268191                 21.061109       3829518
# 10   247515330         4995     540046                  7.527692       5064801
# ...

# %% [markdown]
# Now that we have standardize the data, we are able to calculate the mean for each dataset.

# %%
# calculate mean of each dataset and input into new data frame
meanOfTwitchData= []
for i in range(len(twitch2019And2020Data)):
    meanOfTwitchData.append(twitch2019And2020Data[i].mean())      
meanOfTwitchData[0]
# Out:
# Watch time                  2.092014e+08
# Stream time                 1.436310e+04
# Followers                   3.253762e+06
# Followers gained percent    3.364383e+00
# Views gained                4.498842e+06
# dtype: float64

# %% [markdown]
# Since all of the dataframes in meanOfTwitchData have the same columns names and shape size, we are able to merge them into one dataframe.

# %%
meanOf2019Data = []
meanOf2020Data = []
for i in range(len(meanOfTwitchData)):
    if (i < 12):
        meanOf2019Data.append(meanOfTwitchData[i])
    else:
        meanOf2020Data.append(meanOfTwitchData[i])

# %%
df = pd.DataFrame(data=meanOfTwitchData) 
df2019 = pd.DataFrame(data=meanOf2019Data) 
df2020 = pd.DataFrame(data=meanOf2020Data)

# %%
df2019
# Out:
#      Watch time  Stream time   Followers  Followers gained percent  \
# 0   209201382.6      14363.1  3253762.00                  3.364383
# 1   221850504.9      14611.8  3190304.40                  3.840984
# 2   234208392.3      16997.4  2972227.60                  5.123747
# 3   200016601.2      13920.3  3094471.10                  3.173855
# 4   215793332.7      16003.2  3035476.70                  4.629738
# 5   221869355.7      14754.0  2953983.84                  2.615978
# 6   209149803.9      14958.9  2791761.06                  3.641863
# 7   256546738.2      12713.4  2624188.92                  4.285321
# 8   184612988.7      13045.5  2970375.98                  4.408761
# 9   209689442.7      14851.5  3337969.62                  2.227711
# 10  162797187.0      14646.6  2901734.78                  2.003992
# 11  148392190.5      13292.7  2866367.58                  1.982186
#
#     Views gained
# 0     4498841.84
# 1     5248282.12
# 2     5884129.72
# 3     5153637.26
# ...

# %%
df2020
# Out:
#      Watch time  Stream time   Followers  Followers gained percent  \
# 0   191787729.9      13939.5  3025844.46                  2.842344
# 1   193902606.3      13767.6  2746108.34                  3.353091
# 2   204077463.3      14684.7  3148096.94                  3.038595
# 3   413025024.0      15202.8  3452284.98                 10.370438
# 4   290963583.3      15144.0  3462103.78                  4.966135
# 5   277169642.4      12798.6  3409777.38                  5.098800
# 6   245239488.0      11999.1  3615419.26                  4.080039
# 7   288079790.4      14678.4  3793416.78                  3.781787
# 8   275107432.2      14258.4  4130314.60                  3.188154
# 9   328117519.8      13391.1  3993986.26                  3.679921
# 10  292219196.1      13711.5  4024418.56                  4.000141
# 11  317633671.2      13724.1  3945220.60                  7.836726
#
#     Views gained
# 0     4683953.18
# 1     5390769.00
# 2     5489537.70
# 3     8965265.00
# ...

# %%
df
# Out:
#      Watch time  Stream time   Followers  Followers gained percent  \
# 0   209201382.6      14363.1  3253762.00                  3.364383
# 1   221850504.9      14611.8  3190304.40                  3.840984
# 2   234208392.3      16997.4  2972227.60                  5.123747
# 3   200016601.2      13920.3  3094471.10                  3.173855
# 4   215793332.7      16003.2  3035476.70                  4.629738
# 5   221869355.7      14754.0  2953983.84                  2.615978
# 6   209149803.9      14958.9  2791761.06                  3.641863
# 7   256546738.2      12713.4  2624188.92                  4.285321
# 8   184612988.7      13045.5  2970375.98                  4.408761
# 9   209689442.7      14851.5  3337969.62                  2.227711
# 10  162797187.0      14646.6  2901734.78                  2.003992
# 11  148392190.5      13292.7  2866367.58                  1.982186
# 12  191787729.9      13939.5  3025844.46                  2.842344
# ...

# %% [markdown]
# Our data is now clean and ready to use for analysis. We removed the columns that contained streamer usernames for ethical purposes. We also removed any variables that were not necessary for our data, which include the columns, 'Partnered’, 'Channel', 'Mature', 'Language', and 'Peak Viewers', ‘Average Viewers’. The first four columns listed do not provide us with information relating to the formation or absence of parasocial relationships, rather it describes the type of content a streamer is making. The ‘Peak Viewers’ and ‘Average Viewers’ column is unnecessary because we are looking at new relationships that are formed; looking at the ‘Views Gained’ and ‘Followers Gained’ will describe new activity from the users.
#
# In order to standardize the data, we converted both the followers and views gained into a percentage to keep the data consistent for both smaller and larger streamers. Taking each of our clean monthly datasets, we found the mean of each column and combined them into two datasets, one for each year with twelve months each.

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# First, we run pairplot to see if there us any indication of a crrelation between each column in the given dataset.

# %%
sns.pairplot(data=df)

# %% [markdown]
# Based on the pairplot finding, there is no immediate correlation that we can identify from the pairplot. However, that does not neccessarily mean that there are no correlations within the data. Further analysis on the data would have to be done to idenitfy correlations within specific categories.

# %%
df['Watch time'].plot(kind='bar')
plt.title('Watch Time over the Months')
plt.ylabel('Watch Time')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# The barplot describing the watch time over the two years shows a large spike at month 15.
# Months 0-11 are the consecutive months of 2019. Months 12-23 are the consecutive months of 2020.
# Month 15 would be April 2020. This is around the time that most countries have a presence of Covid
# and are in some form of lockdown. During this time, based on our barplot we can say that twitch users
# were increasingly watching streams. After month 15, we still see a general increase in the watch time.

# %%
df['Stream time'].plot(kind='bar')
plt.title('Stream Time over the Months')
plt.ylabel('Stream Time')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# This barplot shows the stream time from 2019-2020, with hours streamed shown on the y-axis.
# Overall, there is a slight decrease in stream time as time goes on. Months 2 and 4 have the highest hours
# of stream time, and months 6, 7, 18 and 19 have a notably lower number of hours streamed.

# %%
df['Followers gained percent'].plot(kind='bar')
plt.title('Percent of Followers Gained over the Months')
plt.ylabel('Percent of Followers Gained')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# This barplot depicts the percentage of followers gained on Twitch each month.
# Months 9-11, at the end of 2019, have the lowest percent of followers gained.
# Noticeably, month 15 ( April 2020), when lockdown is implemented for many countries, sees
# a large increase in followers gained–at double the average percentages of the other months.
# On average, months 15-23, which match the time of lockdown for many countries, see a larger
# increase in percent of followers gained, than the months preceding them.

# %%
df['Views gained'].plot(kind='bar')
plt.title('Percent of Followers Gained over the Months')
plt.ylabel('Percent of Followers Gained')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# This barplot shows the number of views gained, in millions, per month over the course of two years.
# From months 1-9, the number of views gained is fairly stable, at around 5-6 million.
# There is a dip in the number of views towards the end of 2019 and into 2020 (months 10-12).
# While month 13 and 14 match the trend of months 1-9, month 15 again sees a spike in Twitch activity,
# going over 9 million views gained. Afterwards, the average number of views gained is also higher than before
# month 15.

# %%
df['Views gained'].plot(kind='bar')
plt.title('Views Gained over the Months')
plt.ylabel('Views Gained')
plt.xlabel('Month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pc/ch66yl6j0594d4xzbcrzqmkh0000gp/T/ipykernel_7130/1018428218.py in <module>
# ----> 1 df['Views gained'].plot(kind='bar')
#       2 plt.title('Views Gained over the Months')
#       3 plt.ylabel('Views Gained')
#       4 plt.xlabel('Month')
#
# NameError: name 'df' is not defined

# %% [markdown]
# This barplot shows the number of views gained, in millions, per month over the course of two years.
# From months 1-9, the number of views gained is fairly stable, at around 5-6 million.
# There is a dip in the number of views towards the end of 2019 and into 2020 (months 10-12).
# While month 13 and 14 match the trend of months 1-9, month 15 again sees a spike in Twitch activity,
# going over 9 million views gained. Afterwards, the average number of views gained is also higher than before
# month 15.

# %%
sns.lmplot(x="Views gained", y="Followers gained percent", data=df2019, aspect=2)
plt.title('Views Gained vs. Followers gained percent 2019')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %%
sns.lmplot(y="Followers gained percent", x="Views gained", data=df2020, aspect=2)
plt.title('Views Gained vs. Followers gained percent 2020')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %% [markdown]
# The two graphs above show the correlation between followers gained as a percent and views gained for the years 2019 and 2020 respectively. These graphs show that there was a positive correlation, indicated by the positive, or upward, slope. The relationship is relatively strong, with multiple points being found close to the linear regression line, suggesting that followers gained may be related to viewers gained. This relationship is slightly stronger in 2019 compared to 2020, indicated by the points’ closer proximity to the linear regression line in 2019.

# %%
sns.lmplot(y="Followers gained percent", x="Watch time", data=df2019, aspect=2)
plt.title('Percentage of Followers Gained vs. Watch Time 2019')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %%
sns.lmplot(y="Followers gained percent", x="Watch time", data=df2020, aspect=2)
plt.title('Percentage of Followers Gained vs. Watch Time 2020')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %% [markdown]
# The above two graphs describe the Percent of Followers Gained as a function of Watch Time for both 2019 and 2020, respectively. Both graphs have a positive correlation, meaning that as watch time increases, the percentage of followers gained tends to increase as well; however, 2019 has more outliers than 2020.

# %%
sns.lmplot(y="Followers gained percent", x="Stream time", data=df2019, aspect=2)
plt.title('Followers gained percent vs. Stream Time 2019')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %%
sns.lmplot(y="Followers gained percent", x="Stream time", data=df2020, aspect=2)
plt.title('Followers gained percent vs. Stream Time 2020')
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %% [markdown]
# The two graphs above depict the correlation between percentage of followers gained and stream time during 2019 and 2020, respectively. Looking at the slope of both graphs, it seems that stream time doesn’t increase as much with an increase in followers gained. Both graphs show a fairly weaker correlation between these two variables, but 2020 has a weaker correlation than 2019.

# %%
sns.heatmap(df2019.loc[:, ['Stream time', 'Watch time', 'Followers gained percent', 'Views gained']].corr(), annot=True, vmin=-1, vmax=1)
plt.title('Heatmap of All Variables Considered 2019')
# Out:
# Text(0.5, 1.0, 'Heatmap of All Variables Considered 2019')

# %%
sns.heatmap(df2020.loc[:, ['Stream time', 'Watch time', 'Followers gained percent', 'Views gained']].corr(), annot=True, vmin=-1, vmax=1)
plt.title('Heatmap of All Variables Considered 2020')
# Out:
# Text(0.5, 1.0, 'Heatmap of All Variables Considered 2020')

# %%
sns.heatmap(df.loc[:, ['Stream time', 'Watch time', 'Followers gained percent', 'Views gained']].corr(), annot=True, vmin=-1, vmax=1)
plt.title('Heatmap of All Variables Considered')
# Out:
# Text(0.5, 1.0, 'Heatmap of All Variables Considered')

# %% [markdown]
# We created three heatmaps to visualize correlations: the first to describe all variables from 2019, the second to describe variables from 2020, and the last heatmap to understand the correlation of our data overall (including both years). In all three of our heatmaps, the percentage of Followers Gained has a higher positive correlation with Watch Time and Views Gained. This means that there is an increase in the number of new interactions by Twitch users with top streamers over the course of the two years (2019 and 2020). Stream time shows very low positive correlations with the other variables, meaning that the hours streamed by top streamers over the two years had little correlation with the user interactions.

# %%
def find_outliers(column):
    col_mean = df[column].mean()
    col_sd = np.std(df[column])
    outliers = []

    for item in df[column]:
        if item > (col_mean + (col_sd * 2)):
            outliers.append(item)
        elif item < (col_mean - (col_sd * 2)):
            outliers.append(item)

    return outliers

Watchtime_outliers = find_outliers('Watch time')

Streamtime_outliers = find_outliers('Stream time')

Followers_gained_percent_outliers = find_outliers('Followers gained percent')

Views_gained_outliers = find_outliers('Views gained')
print(Watchtime_outliers, Streamtime_outliers, Followers_gained_percent_outliers, Views_gained_outliers)
# Out:
# [413025024.0] [16997.4, 11999.1] [10.370438465102357, 7.836725776270088] [3117544.18, 8965265.0]

# %% [markdown]
# Through our outlier analysis we found a few outliers within our dataset. The outlier in the Watch time column, first outlier in the Followers gained percent, and second outlier in the Views gained column are all from month 15 which is the month after Covid started, and we believe it is important data to visualize and understand. Including row 15, we have 4 additional rows with outliers. Removing whole rows with outliers would only leave our data with 19 rows and would contradict and affect our time model, so we decided to keep them in our dataset.

# %%
df7 = df[['Views gained', 'Followers gained percent']]
df7.columns = ['Views_gained', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Views_gained ~ Followers_gained_percent', df7) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Views_gained   R-squared:                       0.531
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     24.92
# Date:                Sat, 12 Mar 2022   Prob (F-statistic):           5.37e-05
# Time:                        20:02:17   Log-Likelihood:                -361.46
# No. Observations:                  24   AIC:                             726.9
# Df Residuals:                      22   BIC:                             729.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 3.767e+06   4.44e+05      8.483      0.000    2.85e+06    4.69e+06
# ...

# %%
df6 = df[['Watch time', 'Followers gained percent']]
df6.columns = ['Watch_time', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Watch_time ~ Followers_gained_percent', df6) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Watch_time   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     35.25
# Date:                Sat, 12 Mar 2022   Prob (F-statistic):           5.64e-06
# Time:                        20:02:17   Log-Likelihood:                -451.95
# No. Observations:                  24   AIC:                             907.9
# Df Residuals:                      22   BIC:                             910.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 1.366e+08   1.93e+07      7.090      0.000    9.67e+07    1.77e+08
# ...

# %% [markdown]
# We conducted an OLS regression for the combined dataframe of 2019 and 2020.Our results showed a p-value of 0.00 for both dataframes, meaning we can reject the null hypothesis. This means the predicator value “Followers gained percent” is related to changes in the response variable “Watch time” and “Views gained”.

# %%
df8 = df[['Followers gained percent', 'Watch time', 'Stream time']]
df8.columns = ['Followers_gained_percent', 'Watch_time', 'Stream_time']
(outcome, predictors) = patsy.dmatrices('Followers_gained_percent ~ Watch_time + Stream_time', df8) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Followers_gained_percent   R-squared:                       0.629
# Model:                                  OLS   Adj. R-squared:                  0.593
# Method:                       Least Squares   F-statistic:                     17.77
# Date:                      Sat, 12 Mar 2022   Prob (F-statistic):           3.04e-05
# Time:                              20:02:17   Log-Likelihood:                -36.174
# No. Observations:                        24   AIC:                             78.35
# Df Residuals:                            21   BIC:                             81.88
# Df Model:                                 2
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %% [markdown]
# In order to check if stream time is a potential confounding variable, we added the variable stream time to the equations of the OLS for the combined data frame for both watch time and viewers gained. It can still be seen that the p-values of both OLS for watch time and views gained was less than 0.05, meaning that stream time did not affect the significance. The stream time p-value for both was not significant, meaning that there was no relationship between stream time and the other variables.

# %%
df2 = df2019[['Views gained', 'Followers gained percent']]
df2.columns = ['Views_gained', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Views_gained ~ Followers_gained_percent', df2) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Views_gained   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.561
# Method:                 Least Squares   F-statistic:                     15.07
# Date:                Sat, 12 Mar 2022   Prob (F-statistic):            0.00305
# Time:                        20:02:17   Log-Likelihood:                -174.50
# No. Observations:                  12   AIC:                             353.0
# Df Residuals:                      10   BIC:                             354.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 2.988e+06   5.56e+05      5.374      0.000    1.75e+06    4.23e+06
# ...

# %%
df3 = df2020[['Views gained', 'Followers gained percent']]
df3.columns = ['Views_gained', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Views_gained ~ Followers_gained_percent', df3) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Views_gained   R-squared:                       0.462
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                     8.573
# Date:                Sat, 12 Mar 2022   Prob (F-statistic):             0.0151
# Time:                        20:02:17   Log-Likelihood:                -180.66
# No. Observations:                  12   AIC:                             365.3
# Df Residuals:                      10   BIC:                             366.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 4.843e+06   6.35e+05      7.630      0.000    3.43e+06    6.26e+06
# ...

# %%
df4 = df2019[['Watch time', 'Followers gained percent']]
df4.columns = ['Watch_time', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Watch_time ~ Followers_gained_percent', df4) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Watch_time   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.332
# Method:                 Least Squares   F-statistic:                     6.470
# Date:                Sat, 12 Mar 2022   Prob (F-statistic):             0.0292
# Time:                        20:02:17   Log-Likelihood:                -219.97
# No. Observations:                  12   AIC:                             443.9
# Df Residuals:                      10   BIC:                             444.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 1.463e+08   2.46e+07      5.951      0.000    9.15e+07    2.01e+08
# ...

# %%
df5 = df2020[['Watch time', 'Followers gained percent']]
df5.columns = ['Watch_time', 'Followers_gained_percent']
(outcome, predictors) = patsy.dmatrices('Followers_gained_percent ~ Watch_time', df5) 
mod_log = sm.OLS(outcome, predictors)
res_log = mod_log.fit()
print(res_log.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Followers_gained_percent   R-squared:                       0.638
# Model:                                  OLS   Adj. R-squared:                  0.602
# Method:                       Least Squares   F-statistic:                     17.65
# Date:                      Sat, 12 Mar 2022   Prob (F-statistic):            0.00183
# Time:                              20:02:17   Log-Likelihood:                -20.091
# No. Observations:                        12   AIC:                             44.18
# Df Residuals:                            10   BIC:                             45.15
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.1599      1.912     -1.653      0.129      -7.420       1.100
# ...

# %% [markdown]
# In these above OLS regression tests, we are using the separate 2019 and 2020 data frames rather than the combined one to test each variable before covid and during. It can also be seen that the p-values are less than 0.05 meaning we can reject the null hypothesis that followers gained are not correlated with both watch time and new viewers during both 2019 and 2020. We are however getting the warnings that n<20 because our dataframes only contain 12 data points. Also for watch time and followers gained in 2020 OLS, we have a strong multicollinearity meaning that the two variables could have a strong correlation.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Is our data ethically sourced?<br>
# All of our data is from SullyGnome.com, a website that is open to public and academic use. Because of this, there are not many privacy or ethical concerns about using this data.
# We also followed the website’s Terms and Conditions, in that we give credit to the site here, did not take large amounts of data from the site, and did not use any form of automated scraping on the site.
#
# Is our data respectful of Twitch users’ privacy?<br>
# We decided to focus our analysis on the numerical means of stream time, watch time, and followers gained per month for the top streamers of Twitch. Because we are using the means of stream time and viewers for every month, and have removed streamers’ usernames and languages from our data, there should be no personally identifiable data on the streamers in our dataset. Our data also does not include any personal information on their viewers, but simply the sum and mean of time watched and followers gained. Since the data includes no personally identifiable information about the viewers either, our data collection and analysis method should eliminate privacy concerns regarding Twitch users–for both streamers and viewers.
#
# Is our data and data analysis unbiased? <br>
# Because SullyGnome.com collects this data through the Twitch API, the data cannot be influenced by human bias. The data is numerical by nature, and there is thus no possibility of human influence or experimenter bias. Our analysis should not be biased either, since our analysis did not aim to manipulate the data itself, but visualize and seek to explain trends in the larger dataset of Twitch behavior during 2019 and 2020.
#
# Are there any ethical or privacy concerns with our data analysis or results? <br>
# Our data analysis should not cause any personal harm or cause any privacy harm because of the lack of personally identifiable data. Our data cleaning removed streamers’ Twitch usernames, and the rest of the data focuses on aggregated values. Our analyses and graphs are built off of this largely ethical data, as we focused on the correlation between different variables.<br>
# The result of our analyses should not cause any ethical or privacy concerns for similar reasons as listed above. We did find that there was a decrease in correlation between followers gained and views gained during 2020; as a result, this information can not be validly used to assume anything about Twitch engagement. While we did find that there was an increase in correlation between followers gained and watch time in 2020, these results are unlikely to be used for personal harm; they demonstrate a larger trend of increased follower engagement during 2020. Because the results are about a group of Twitch users, cannot be extrapolated to assume anything, harmful or beneficial, about individuals.

# %% [markdown]
# # Conclusion

# %% [markdown]
# From our analysis, we conclude that there was not a strong correlation between the top Twitch streamers’ number of followers gained and 1) New Viewers and 2) Watch Time, during the pandemic (2020). This means that the Twitch users' activity was not strongly correlated with the formation of a parasocial relationship.
#
# Running an OLS data analysis showed a significant relationship (p-value = 0.00 <0.05) between our variables of Followers Gained and 1) Views Gained and 2) Watch Time. When we look at the specific R-squared values for these variables, we can understand how the correlation changed during Covid compared to before.
#
# Overall, including both 2019 and 2020, Followers Gained had a moderately positive correlation with Views gained as well as Watch Time. This showed that with an increase of new users who watched a stream and the length of time streams were watched, there was also an increase in the number of followers a streamer had. When looking at Followers Gained versus Views Gained, we observed a decrease in this correlation during Covid, compared to the year before. When looking at Followers Gained vs Watch Time, we observe an increase in correlation during Covid. However, overall, these were all moderate, not strong, correlations.

# %% [markdown]
# # Discussion

# %% [markdown]
# We believe that including a larger number of data points would provide more accurate results. Originally, we only observed the top 50 streamers; taking a look at the top 1000 streamers over the two years may be more helpful and paint a more accurate picture of how trends have changed between 2019 and 2020.
#
# Something we would like to include if we were to further this project is to utilize data describing new subscribers and the type of subscribers that a streamer gained. On Twitch, subscribing to a streamer costs money; however, following someone is much easier. Oftentimes, a Twitch user may not interact with the streamers they follow as much as those they subscribe to. Using this stronger measure of commitment to the media figure would be more beneficial for our understanding of parasocial relationships.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# Arushri Girish<br>
# - Overview, Background, Data Visualization, Conclusion and Discussion
#
# Ronaldo Garcia-Hernandez<br>
# - Data cleaning, EDA, Linear Regression, and Data description
#
# Matthew Bernard<br>
# - Data Cleaning, EDA, Data Visualization, Data Description
#
# Daisy Ye<br>
# - Data Visualization, Ethics and Privacy, Outliers Code, Editing
#
# Jocelyn Quiroz<br>
# - Background, Data Visualization, Editing, Outliers code
